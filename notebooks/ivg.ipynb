# %%
import pandas as pd
from time import sleep
import requests
from dotenv import load_dotenv
import os

# %%
# Load environment variables
load_dotenv()

headers = {
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.7',
    'Authorization': 'Bearer null',
    'Connection': 'keep-alive',
    'Referer': 'https://salute.regione.veneto.it/ivgStatistiche/',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-GPC': '1',
    'User-Agent': os.getenv('USER_AGENT'),
    'dnt': '1',
    'sec-ch-ua': f'"Brave";v="{os.getenv("BROWSER_VERSION")}", "Chromium";v="{os.getenv("BROWSER_VERSION")}", "Not_A Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': f'"{os.getenv("PLATFORM")}"',
}

# %%
aziende_ids = list(range(101, 123)) + list(range(501, 510)) + [901, 912]

anni_search = [1,2,3,4,5,6,7,8,9]

# Initialize empty lists to store the data
nomi = []
valori = []
anni = []

for anno in anni_search: 
  for aziende_id in aziende_ids:
    params = {
      'annoA': anno,
      'annoDa': anno,
      'idAzienda': aziende_id,
      'idTipoGrafico': '8',
      'isCategoriaEnable': 'false',
      'isCategoriaMax1': 'false',
    }

    response = requests.get('https://salute.regione.veneto.it/ivgStatistiche/api/grafico', params=params, headers=headers)
    data = response.json()

    if 'graficoTortaDto' not in data or data['graficoTortaDto'] is None:
        print(f"Skipping azienda {aziende_id} for year {anno} - no data found")
        continue

    aziende = data['graficoTortaDto']
    for azienda in aziende:
      nome = azienda['name']
      valore = azienda['value']
      print(f"{anno} - IVG {nome}: {valore}")

      # Append each nome and valore to their respective lists
      nomi.append(nome)
      valori.append(valore)
      anni.append(anno)

    sleep(1)

# Create the DataFrame after the loop is complete
df = pd.DataFrame({
    'nome_azienda': nomi,
    'valore': valori,
    'anno': anni
})
# Out:
# 1 - IVG 101 - BELLUNO: 96.0
# 1 - IVG 102 - FELTRE: 120.0
# 1 - IVG 103 - BASSANO DEL GRAPPA: 128.0
# 1 - IVG 104 - THIENE: 183.0
# 1 - IVG 105 - ARZIGNANO: 152.0
# 1 - IVG 106 - VICENZA: 277.0
# 1 - IVG 107 - PIEVE DI SOLIGO: 314.0
# 1 - IVG 108 - ASOLO: 299.0
# 1 - IVG 109 - TREVISO: 358.0
# 1 - IVG 110 - S. DONA' DI PIAVE: 144.0
# Skipping azienda 111 for year 1 - no data found
# 1 - IVG 112 - VENEZIANA: 496.0
# 1 - IVG 113 - MIRANO: 342.0
# 1 - IVG 114 - CHIOGGIA: 59.0
# 1 - IVG 115 - CITTADELLA: 178.0
# 1 - IVG 116 - PADOVA: 169.0
# 1 - IVG 117 - ESTE: 134.0
# 1 - IVG 118 - ROVIGO: 185.0
# 1 - IVG 119 - ADRIA: 32.0
# 1 - IVG 120 - VERONA: 141.0
# 1 - IVG 121 - LEGNAGO: 104.0
# 1 - IVG 122 - BUSSOLENGO: 52.0
# 1 - IVG 901 - AZIENDA OSPEDALE - UNIVERSITÀ PADOVA: 349.0
# 1 - IVG 912 - A.O. INTEGRATA CON UNIVERSITÀ - VERONA: 731.0
# 2 - IVG 101 - BELLUNO: 78.0
# 2 - IVG 102 - FELTRE: 121.0
# 2 - IVG 103 - BASSANO DEL GRAPPA: 105.0
# 2 - IVG 104 - THIENE: 200.0
# 2 - IVG 105 - ARZIGNANO: 163.0
# 2 - IVG 106 - VICENZA: 297.0
# 2 - IVG 107 - PIEVE DI SOLIGO: 269.0
# 2 - IVG 108 - ASOLO: 245.0
# 2 - IVG 109 - TREVISO: 407.0
# 2 - IVG 110 - S. DONA' DI PIAVE: 134.0
# Skipping azienda 111 for year 2 - no data found
# 2 - IVG 112 - VENEZIANA: 462.0
# 2 - IVG 113 - MIRANO: 365.0
# 2 - IVG 114 - CHIOGGIA: 83.0
# 2 - IVG 115 - CITTADELLA: 210.0
# 2 - IVG 116 - PADOVA: 181.0
# 2 - IVG 117 - ESTE: 136.0
# 2 - IVG 118 - ROVIGO: 149.0
# 2 - IVG 119 - ADRIA: 45.0
# 2 - IVG 120 - VERONA: 124.0
# 2 - IVG 121 - LEGNAGO: 102.0
# 2 - IVG 122 - BUSSOLENGO: 111.0
# 2 - IVG 901 - AZIENDA OSPEDALE - UNIVERSITÀ PADOVA: 323.0
# 2 - IVG 912 - A.O. INTEGRATA CON UNIVERSITÀ - VERONA: 729.0
# Skipping azienda 111 for year 3 - no data found
# 3 - IVG 501 - AZIENDA ULSS N. 1 DOLOMITI: 197.0
# 3 - IVG 502 - AZIENDA ULSS N. 2 MARCA TREVIGIANA: 833.0
# 3 - IVG 503 - AZIENDA ULSS N. 3 SERENISSIMA: 795.0
# 3 - IVG 504 - AZIENDA ULSS N. 4 VENETO ORIENTALE: 123.0
# 3 - IVG 505 - AZIENDA ULSS N. 5 POLESANA: 220.0
# 3 - IVG 506 - AZIENDA ULSS N. 6 EUGANEA: 524.0
# 3 - IVG 507 - AZIENDA ULSS N. 7 PEDEMONTANA: 312.0
# 3 - IVG 508 - AZIENDA ULSS N. 8 BERICA: 407.0
# 3 - IVG 509 - AZIENDA ULSS N. 9 SCALIGERA: 410.0
# 3 - IVG 901 - AZIENDA OSPEDALE - UNIVERSITÀ PADOVA: 324.0
# 3 - IVG 912 - A.O. INTEGRATA CON UNIVERSITÀ - VERONA: 607.0
# Skipping azienda 111 for year 4 - no data found
# 4 - IVG 501 - AZIENDA ULSS N. 1 DOLOMITI: 203.0
# 4 - IVG 502 - AZIENDA ULSS N. 2 MARCA TREVIGIANA: 820.0
# 4 - IVG 503 - AZIENDA ULSS N. 3 SERENISSIMA: 818.0
# 4 - IVG 504 - AZIENDA ULSS N. 4 VENETO ORIENTALE: 108.0
# 4 - IVG 505 - AZIENDA ULSS N. 5 POLESANA: 248.0
# 4 - IVG 506 - AZIENDA ULSS N. 6 EUGANEA: 552.0
# 4 - IVG 507 - AZIENDA ULSS N. 7 PEDEMONTANA: 233.0
# 4 - IVG 508 - AZIENDA ULSS N. 8 BERICA: 417.0
# 4 - IVG 509 - AZIENDA ULSS N. 9 SCALIGERA: 405.0
# 4 - IVG 901 - AZIENDA OSPEDALE - UNIVERSITÀ PADOVA: 264.0
# 4 - IVG 912 - A.O. INTEGRATA CON UNIVERSITÀ - VERONA: 551.0
# Skipping azienda 111 for year 5 - no data found
# 5 - IVG 501 - AZIENDA ULSS N. 1 DOLOMITI: 177.0
# 5 - IVG 502 - AZIENDA ULSS N. 2 MARCA TREVIGIANA: 747.0
# 5 - IVG 503 - AZIENDA ULSS N. 3 SERENISSIMA: 736.0
# 5 - IVG 504 - AZIENDA ULSS N. 4 VENETO ORIENTALE: 121.0
# 5 - IVG 505 - AZIENDA ULSS N. 5 POLESANA: 186.0
# 5 - IVG 506 - AZIENDA ULSS N. 6 EUGANEA: 492.0
# 5 - IVG 507 - AZIENDA ULSS N. 7 PEDEMONTANA: 270.0
# 5 - IVG 508 - AZIENDA ULSS N. 8 BERICA: 381.0
# 5 - IVG 509 - AZIENDA ULSS N. 9 SCALIGERA: 417.0
# 5 - IVG 901 - AZIENDA OSPEDALE - UNIVERSITÀ PADOVA: 254.0
# 5 - IVG 912 - A.O. INTEGRATA CON UNIVERSITÀ - VERONA: 570.0
# Skipping azienda 111 for year 6 - no data found
# 6 - IVG 501 - AZIENDA ULSS N. 1 DOLOMITI: 171.0
# 6 - IVG 502 - AZIENDA ULSS N. 2 MARCA TREVIGIANA: 746.0
# 6 - IVG 503 - AZIENDA ULSS N. 3 SERENISSIMA: 677.0
# 6 - IVG 504 - AZIENDA ULSS N. 4 VENETO ORIENTALE: 104.0
# 6 - IVG 505 - AZIENDA ULSS N. 5 POLESANA: 181.0
# 6 - IVG 506 - AZIENDA ULSS N. 6 EUGANEA: 446.0
# 6 - IVG 507 - AZIENDA ULSS N. 7 PEDEMONTANA: 275.0
# 6 - IVG 508 - AZIENDA ULSS N. 8 BERICA: 376.0
# 6 - IVG 509 - AZIENDA ULSS N. 9 SCALIGERA: 302.0
# 6 - IVG 901 - AZIENDA OSPEDALE - UNIVERSITÀ PADOVA: 324.0
# 6 - IVG 912 - A.O. INTEGRATA CON UNIVERSITÀ - VERONA: 527.0
# Skipping azienda 111 for year 7 - no data found
# 7 - IVG 501 - AZIENDA ULSS N. 1 DOLOMITI: 145.0
# 7 - IVG 502 - AZIENDA ULSS N. 2 MARCA TREVIGIANA: 770.0
# 7 - IVG 503 - AZIENDA ULSS N. 3 SERENISSIMA: 617.0
# 7 - IVG 504 - AZIENDA ULSS N. 4 VENETO ORIENTALE: 101.0
# 7 - IVG 505 - AZIENDA ULSS N. 5 POLESANA: 188.0
# 7 - IVG 506 - AZIENDA ULSS N. 6 EUGANEA: 451.0
# 7 - IVG 507 - AZIENDA ULSS N. 7 PEDEMONTANA: 315.0
# 7 - IVG 508 - AZIENDA ULSS N. 8 BERICA: 327.0
# 7 - IVG 509 - AZIENDA ULSS N. 9 SCALIGERA: 306.0
# 7 - IVG 901 - AZIENDA OSPEDALE - UNIVERSITÀ PADOVA: 310.0
# 7 - IVG 912 - A.O. INTEGRATA CON UNIVERSITÀ - VERONA: 556.0
# Skipping azienda 111 for year 8 - no data found
# 8 - IVG 501 - AZIENDA ULSS N. 1 DOLOMITI: 139.0
# 8 - IVG 502 - AZIENDA ULSS N. 2 MARCA TREVIGIANA: 804.0
# 8 - IVG 503 - AZIENDA ULSS N. 3 SERENISSIMA: 660.0
# 8 - IVG 504 - AZIENDA ULSS N. 4 VENETO ORIENTALE: 112.0
# 8 - IVG 505 - AZIENDA ULSS N. 5 POLESANA: 177.0
# 8 - IVG 506 - AZIENDA ULSS N. 6 EUGANEA: 478.0
# 8 - IVG 507 - AZIENDA ULSS N. 7 PEDEMONTANA: 340.0
# 8 - IVG 508 - AZIENDA ULSS N. 8 BERICA: 321.0
# 8 - IVG 509 - AZIENDA ULSS N. 9 SCALIGERA: 367.0
# 8 - IVG 901 - AZIENDA OSPEDALE - UNIVERSITÀ PADOVA: 269.0
# 8 - IVG 912 - A.O. INTEGRATA CON UNIVERSITÀ - VERONA: 607.0
# Skipping azienda 111 for year 9 - no data found
# 9 - IVG 501 - AZIENDA ULSS N. 1 DOLOMITI: 156.0
# 9 - IVG 502 - AZIENDA ULSS N. 2 MARCA TREVIGIANA: 793.0
# 9 - IVG 503 - AZIENDA ULSS N. 3 SERENISSIMA: 644.0
# 9 - IVG 504 - AZIENDA ULSS N. 4 VENETO ORIENTALE: 74.0
# 9 - IVG 505 - AZIENDA ULSS N. 5 POLESANA: 146.0
# 9 - IVG 506 - AZIENDA ULSS N. 6 EUGANEA: 531.0
# 9 - IVG 507 - AZIENDA ULSS N. 7 PEDEMONTANA: 337.0
# 9 - IVG 508 - AZIENDA ULSS N. 8 BERICA: 408.0
# 9 - IVG 509 - AZIENDA ULSS N. 9 SCALIGERA: 405.0
# 9 - IVG 901 - AZIENDA OSPEDALE - UNIVERSITÀ PADOVA: 257.0
# 9 - IVG 912 - A.O. INTEGRATA CON UNIVERSITÀ - VERONA: 516.0

# %%
anni_mapping = {
    1: 2015,
    2: 2016,
    3: 2017,
    4: 2018,
    5: 2019,
    6: 2020,
    7: 2021,
    8: 2022,
    9: 2023
}
df['anno_id'] = df['anno']
df['anno'] = df['anno_id'].map(anni_mapping)
df['valore'] = df['valore'].astype(int)

# %%
df.to_csv('../output/ivg_effettuate.csv', index=False, encoding='UTF-8')
